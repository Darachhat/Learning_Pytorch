# %% [markdown]
# <a href="https://colab.research.google.com/github/Darachhat/Pytorch-Intro/blob/main/Intro_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
import torch

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# accelerate                       0.33.0
# aiohappyeyeballs                 2.4.0
# aiohttp                          3.10.5
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albucore                         0.0.14
# albumentations                   1.4.14
# altair                           4.2.2
# annotated-types                  0.7.0
# anyio                            3.7.1
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array_record                     0.5.1
# arviz                            0.18.0
# asn1crypto                       1.5.1
# astropy                          6.1.3
# astropy-iers-data                0.2024.8.27.10.28.29
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.1.0
# ...
